# %% [markdown]
# **Before running the image flattening operations please follow these steps**
#
#     1. Place all images to be flattened in the "images" folder within the texture tools folder
#     2. Make sure python is installed
#     3. For the first time use of this tool please run the pip install below to avoid a OpenCV error
#     4. Make sure to run the correct line for the OS on your PC

# %%
# %pip install opencv-python

# %% [markdown]
# **Run this code for Windows PCs**

# %%
import os, subprocess
import sys
subprocess.call(["python", "run_docscan.py","images"])
# Out:
# 0

# %% [markdown]
# **Run this code for MAC**

# %%
import os, subprocess
import sys
subprocess.call(["python3.8", "docscan_args.py", "images"])

# %% [markdown]
# The output folder shows the result of images texturing, please use the pngs in final textures folder for use in 3D scenes.
